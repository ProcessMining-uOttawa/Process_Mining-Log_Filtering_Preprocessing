# %%
# %run ./DataPreprocessing.ipynb
data=readCSV('dataset3.csv','time')

# %%
data
# Out:
#        Unnamed: 0      X     X.                      event  Theme  \
# 0               1      1      1             View Dashboard   Dark
# 1               2      2      2             View Dashboard  Light
# 2               3      3      3                Edit Graphs    NaN
# 3               4      4      4                Graph Saved    NaN
# 4               5      5      5             View Dashboard  Light
# ...           ...    ...    ...                        ...    ...
# 24995       24996  24996  24996             View Dashboard   Dark
# 24996       24997  24997  24997  Edit Graph from Dashboard    NaN
# 24997       24998  24998  24998             Add New Button    NaN
# 24998       24999  24999  24999                Edit Graphs    NaN
# 24999       25000  25000  25000             View Dashboard  Light
#
#        Account.Users  Metric.Count Graph.Origin  \
# 0                1.0           NaN          NaN
# 1               41.0           NaN          NaN
# ...

# %%
data=ArrangeRows(data,["Company.ID","time"])

# %%
writeCSV(data, "dataSet123123123.csv")
